# %%
import os
import numpy as np

# %%
stock_files = os.listdir('stocks_by_name')
stock_files.sort()
cnt = 0
# for i in range(len(stock_files)):
for i in range(2):
    lines = open(os.path.join('stocks_by_name', stock_files[i])).readlines()
    for line in lines:
        line = line.strip().split(', ')
        one_id = line[0]
        date = line[1]
        feature = line[2:]
        print(cnt, one_id, date, stock_files[i])
        cnt = cnt + 1

# %%
stock_files = os.listdir('stocks_by_date')
stock_files.sort()
cnt = 0
# for i in range(len(stock_files)):
for i in range(2):
    lines = open(os.path.join('stocks_by_date', stock_files[i])).readlines()
    for line in lines:
        line = line.strip().split(', ')
        one_id = line[0]
        name = line[1]
        feature = line[2:]
        print(cnt, one_id, name, stock_files[i])
        cnt = cnt + 1
# Out:
# (0, '0', '000001.XSHE', '2005-02-01.txt')
# (1, '3153', '000002.XSHE', '2005-02-01.txt')
# (2, '6306', '000004.XSHE', '2005-02-01.txt')
# (3, '12612', '000006.XSHE', '2005-02-01.txt')
# (4, '15765', '000007.XSHE', '2005-02-01.txt')
# (5, '22071', '000009.XSHE', '2005-02-01.txt')
# (6, '25224', '000010.XSHE', '2005-02-01.txt')
# (7, '31530', '000012.XSHE', '2005-02-01.txt')
# (8, '34683', '000014.XSHE', '2005-02-01.txt')
# (9, '37836', '000016.XSHE', '2005-02-01.txt')
# (10, '44142', '000018.XSHE', '2005-02-01.txt')
# (11, '47295', '000019.XSHE', '2005-02-01.txt')
# (12, '53601', '000021.XSHE', '2005-02-01.txt')
# (13, '56754', '000022.XSHE', '2005-02-01.txt')
# (14, '59907', '000023.XSHE', '2005-02-01.txt')
# (15, '63060', '000024.XSHE', '2005-02-01.txt')
# (16, '69366', '000026.XSHE', '2005-02-01.txt')
# (17, '72519', '000027.XSHE', '2005-02-01.txt')
# (18, '75672', '000028.XSHE', '2005-02-01.txt')
# (19, '78825', '000029.XSHE', '2005-02-01.txt')
# ...
